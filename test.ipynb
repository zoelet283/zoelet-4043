# %% [markdown]
# Task 2 Computational Maths

# %% [markdown]
# $\large test$

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.arange(-2*np.pi, 2*np.pi, 0.1)

y=np.sin(x)

plt.plot(x,y)
plt.show()

# %%
x= np.arange(-2*np.pi, 2*np.pi,0.01)

y=np.sqrt(np.sin(x))

plt.plot(x,y)
plt.show()
# Out:
# C:\Users\CompSci\AppData\Local\Temp\ipykernel_2308\2037250225.py:3: RuntimeWarning: invalid value encountered in sqrt
#   y=np.sqrt(np.sin(x))

# %% [markdown]
# $\large Task)$ $\large i$

# %%
x=np.arange(-2*np.pi, 2*np.pi)

y=np.exp(np.sin(-x))
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# task) ii

# %% [markdown]
# task iii

# %%
from random import seed
from random import randint
# seed random number generator
# seed(1)
# generate some integers
for _ in range(1):
	value = randint(100, 999)
	print(value)
# Out:
# 639

# %% [markdown]
# task iv

# %%
for _ in range(1):
  while (randint) == value:
    break
  else:
    print(value)
    value = randint(100, 999)
  #reuse the num generator from iii
  #for loop until orginal number found
print(value)
# Out:
# 791
# 368
